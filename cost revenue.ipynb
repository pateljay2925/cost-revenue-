# %%
import pandas
from pandas import DataFrame
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
data = pandas.read_csv('cost-revenue-dirty (2) - cost-revenue-dirty (1) (1).csv')

# %%
data.describe()
# Out:
#        production_budget_usd  worldwide_gross_usd
# count           5.033000e+03         5.033000e+03
# mean            3.291418e+07         9.517576e+07
# std             4.112751e+07         1.726131e+08
# min             1.100000e+03         4.010000e+02
# 25%             6.000000e+06         7.000000e+06
# 50%             1.900000e+07         3.296865e+07
# 75%             4.200000e+07         1.034529e+08
# max             4.250000e+08         2.783919e+09

# %%
y = DataFrame(data, columns=['worldwide_gross_usd'])
x = DataFrame(data, columns=['production_budget_usd'])

# %%
plt.figure(figsize=(10,6,))
plt.scatter(x,y,)
plt.title('film cost vs globle revenue')
plt.ylabel('worldwide_gross_usd')
plt.xlabel('production_budget_usd')
plt.ylim(0, 3000000000)
plt.xlim(0,450000000)
plt.show()

# %%
regression = LinearRegression()
regression.fit(x, y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
regression.coef_
# Out:
# array([[3.11152465]])

# %%
regression.intercept_
# Out:
# array([-7237521.30517451])

# %%
plt.figure(figsize=(10,6,))
plt.scatter(x,y,alpha=0.3)
plt.plot(x, regression.predict(x),color='red', linewidth=4)
plt.title('film cost vs globle revenue')
plt.ylabel('worldwide_gross_usd')
plt.xlabel('production_budget_usd')
plt.ylim(0, 3000000000)
plt.xlim(0,450000000)
plt.show()

# %%
regression.score(x,y)
# Out:
# 0.5496214454226855
